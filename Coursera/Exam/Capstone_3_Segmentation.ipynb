# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# This notebook is intended for Capstone project week 3.
# In this assignment, we will explore, segment, and cluster the neighborhoods in the city of Toronto. We will collect the data from foursquare , make it in a structured format. Once the data is in a structured format, we will replicate the analysis that we did to the New York City dataset to explore and cluster the neighborhoods in the city of Toronto.

# %% [markdown]
# Before we download the data and start exploring it, let's download some dependencies needed by this notebook

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.0.1-py_0        conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Dataset

# %% [markdown]
# First, we need a dataset file that contain Toronto neighbourhood (Toronto_Neigbourhood_Coordinate.csv) with fields as follow : Postal Code (PostCode), Borough, Neighbourhood, Latitude, Longitude .
# If we run this notebook for the first time, we won't be able to find that file and this notebook will create that file with thise steps :
#     - Get the list of postal code in Toronto from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M . We copy the list of postal code manually and save it in csv file (Toronto.csv), and upload it as asset so this notebook can access it. This file will contain attribute as follow : Postal Code (PostCode), Borough, Neighbourhood.
#     - Load Toronto neighbourhood data from Toronto.csv to dataframe (df_Toronto)
#     - Loop for each neighbourhood in df_Toronto and get each neighbourhood latitude and longitude using geopy.geocoders . After it finish looping, dataframe df_Toronto will contain attribute as follow : Postal Code (PostCode), Borough, Neighbourhood, latitude, longitude
#     - Save the dataframe to csv file (Toronto_Neighbourhood_Coordinate

# %%
isTorontoFileExists = True

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_c8e4850bd8dc439d8772288cbd371cd8 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='wmyv12NJK8swbJlynpLN0_WSnpZSQ6nrEmJPY5dbEOkh',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

bucket_id = 'phytonbasicfords-donotdelete-pr-ksk41itkqmstbb'

body = client_c8e4850bd8dc439d8772288cbd371cd8.get_object(Bucket=bucket_id,Key='Toronto.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
    
    
df_Toronto = pd.read_csv(body)
df_Toronto.head()
# Out:
#   Postcode          Borough     Neighbourhood
# 0      M5R  Central Toronto         Yorkville
# 1      M3J       North York   York University
# 2      M2P       North York   York Mills West
# 3      M2L       North York        York Mills
# 4      M4C        East York  Woodbine Heights

# %% [markdown]
# After we got dataframe of Toronto's neighbourhood, we will try to retrieve dataframe for Toronto's geospatial based on the postal code. The data is retrieved from Toronto_Geospatial_Coordinates.csv

# %%
body = client_c8e4850bd8dc439d8772288cbd371cd8.get_object(Bucket=bucket_id,Key='Toronto_Geospatial_Coordinates.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_geospatial = pd.read_csv(body)

#rename the postal code because it will become a foreign key to dataframe Toronto
df_geospatial.rename(columns={"Postal Code": "Postcode"}, inplace = True )

df_geospatial.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %% [markdown]
# We also need to get dataframe for Toronto Neighbourhood geospatial location. If it execute for the first time, it need to access geocoders first to get the latitude and longitude for each neighbourhood and save it to csv (Toronto_Neighbourhood_Coordinate.csv) file. If it executed for second time and so forth, we just need to read from csv and load it to dataframe.

# %%
#add latitude and longitude column
df_postalcode['latitude']=0.0
df_postalcode['longitude']=0.0
df_postalcode.head()
# Out:
#   Postcode          Borough     Neighbourhood  latitude  longitude
# 0      M5R  Central Toronto         Yorkville       0.0        0.0
# 1      M3J       North York   York University       0.0        0.0
# 2      M2P       North York   York Mills West       0.0        0.0
# 3      M2L       North York        York Mills       0.0        0.0
# 4      M4C        East York  Woodbine Heights       0.0        0.0

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="coursera_exam")

for index, row in df_postalcode.iterrows():
    #if index > 284:
        location = geolocator.geocode("{}, Toronto, Ontario".format(row['Neighbourhood']))
        
        if type(location) != type(None):
            df_postalcode.at[index,'latitude'] = location.latitude
            df_postalcode.at[index,'longitude'] = location.longitude 
        print ("{},{},{},{},{},{}".format( index, row['Postcode'] , row['Borough'] , row['Neighbourhood'], df_postalcode.at[index,'latitude'], df_postalcode.at[index,'longitude']  ))
        
print('finish')
# Out:
# 0,M5R,Central Toronto,Yorkville,43.6713861,-79.3901677
# 1,M3J,North York,York University,43.7792419,-79.4835593
# 2,M2P,North York,York Mills West,43.7440391,-79.406657
# 3,M2L,North York,York Mills,43.7440391,-79.406657
# 4,M4C,East York,Woodbine Heights,43.6999302,-79.3191316
# 5,M4B,East York,Woodbine Gardens,43.7120785,-79.3025673
# 6,M1G,Scarborough,Woburn,43.7598243,-79.2252908
# 7,M3H,North York,Wilson Heights,43.7405195,-79.4400172
# 8,M2R,North York,Willowdale West,43.7615095,-79.4109234
# 9,M2N,North York,Willowdale South,43.7615095,-79.4109234
# 10,M2M,North York,Willowdale,43.7615095,-79.4109234
# 11,M1P,Scarborough,Wexford Heights,43.7432421,-79.304641
# 12,M1R,Scarborough,Wexford,43.7453767,-79.2947155
# 13,M9N,York,Weston,43.7001608,-79.5162474
# 14,M9P,Etobicoke,Westmount,43.6936399,-79.5210426
# 15,M1E,Scarborough,West Hill,43.7689144,-79.1872905
# 16,M9B,Etobicoke,West Deane Park,43.6631995,-79.5685684
# 17,M4A,North York,Victoria Village,43.732658,-79.3111892
# 18,M5L,Downtown Toronto,Victoria Hotel,43.66946915,-79.37326825
# 19,M6L,North York,Upwood Park,43.708654499999994,-79.50254644741823
# 20,M1X,Scarborough,Upper Rouge,43.8049304,-79.1658374
# 21,M5S,Downtown Toronto,University of Toronto,43.663461999999996,-79.39775965337452
# 22,M5J,Downtown Toronto,Union Station,43.6446934,-79.38013200585965
# 23,M5X,Downtown Toronto,Underground city,43.7701454,-79.3748625
# 24,M6J,West Toronto,Trinity,43.665301549999995,-79.39525214965947
# 25,M5J,Downtown Toronto,Toronto Islands,43.6161962,-79.3693582
# 26,M5K,Downtown Toronto,Toronto Dominion Centre,43.6473768,-79.3813719429129
# 27,M4H,East York,Thorncliffe Park,43.704553,-79.3454074
# 28,M9V,Etobicoke,Thistletown,43.7372656,-79.5653169
# 29,M8Z,Etobicoke,The Queensway West,43.6236182,-79.5147637
# 30,M8Y,Etobicoke,The Queensway East,43.6093093,-79.5677317
# 31,M8X,Etobicoke,The Kingsway,43.6473811,-79.5113328
# 32,M6P,West Toronto,The Junction South,43.6654775,-79.470352
# 33,M6N,York,The Junction North,43.6654775,-79.470352
# 34,M4K,East Toronto,The Danforth West,43.6864333,-79.3003555
# 35,M4L,East Toronto,The Beaches West,43.6710244,-79.296712
# 36,M4E,East Toronto,The Beaches,43.6710244,-79.296712
# 37,M5R,Central Toronto,The Annex,43.6703377,-79.407117
# 38,M1T,Scarborough,Tam O'Shanter,43.7810454,-79.2980941
# 39,M6S,West Toronto,Swansea,43.64494,-79.478313
# 40,M8Y,Etobicoke,Sunnylea,43.64159705,-79.5016654011084
# 84,M8X,Etobicoke,Old Mill North,43.649826,-79.4943338
# 85,M9C,Etobicoke,Old Burnhamthorpe,43.6393732,-79.5843869
# 86,M1L,Scarborough,Oakridge,43.6971738,-79.2748232
# 87,M1A,Not assigned,Not assigned,0.0,0.0
# 88,M2A,Not assigned,Not assigned,0.0,0.0
# 89,M8A,Not assigned,Not assigned,0.0,0.0
# 90,M9A,Queen's Park,Not assigned,0.0,0.0
# 91,M2B,Not assigned,Not assigned,0.0,0.0
# 92,M7B,Not assigned,Not assigned,0.0,0.0
# 93,M8B,Not assigned,Not assigned,0.0,0.0
# 94,M2C,Not assigned,Not assigned,0.0,0.0
# 95,M7C,Not assigned,Not assigned,0.0,0.0
# 96,M8C,Not assigned,Not assigned,0.0,0.0
# 97,M2E,Not assigned,Not assigned,0.0,0.0
# 98,M3E,Not assigned,Not assigned,0.0,0.0
# 99,M7E,Not assigned,Not assigned,0.0,0.0
# 100,M8E,Not assigned,Not assigned,0.0,0.0
# 101,M9E,Not assigned,Not assigned,0.0,0.0
# 102,M2G,Not assigned,Not assigned,0.0,0.0
# 103,M3G,Not assigned,Not assigned,0.0,0.0
# 104,M7G,Not assigned,Not assigned,0.0,0.0
# 105,M8G,Not assigned,Not assigned,0.0,0.0
# 106,M9G,Not assigned,Not assigned,0.0,0.0
# 107,M7H,Not assigned,Not assigned,0.0,0.0
# 108,M8H,Not assigned,Not assigned,0.0,0.0
# 109,M9H,Not assigned,Not assigned,0.0,0.0
# 110,M7J,Not assigned,Not assigned,0.0,0.0
# 111,M8J,Not assigned,Not assigned,0.0,0.0
# 112,M9J,Not assigned,Not assigned,0.0,0.0
# 113,M7K,Not assigned,Not assigned,0.0,0.0
# 114,M8K,Not assigned,Not assigned,0.0,0.0
# 115,M9K,Not assigned,Not assigned,0.0,0.0
# 116,M7L,Not assigned,Not assigned,0.0,0.0
# 117,M8L,Not assigned,Not assigned,0.0,0.0
# 118,M7M,Not assigned,Not assigned,0.0,0.0
# 119,M8M,Not assigned,Not assigned,0.0,0.0
# 120,M7N,Not assigned,Not assigned,0.0,0.0
# 121,M8N,Not assigned,Not assigned,0.0,0.0
# 122,M3P,Not assigned,Not assigned,0.0,0.0
# 123,M7P,Not assigned,Not assigned,0.0,0.0
# 124,M8P,Not assigned,Not assigned,0.0,0.0
# 125,M3R,Not assigned,Not assigned,0.0,0.0
# 126,M8R,Not assigned,Not assigned,0.0,0.0
# 127,M2S,Not assigned,Not assigned,0.0,0.0
# 128,M3S,Not assigned,Not assigned,0.0,0.0
# 129,M7S,Not assigned,Not assigned,0.0,0.0
# 130,M8S,Not assigned,Not assigned,0.0,0.0
# 131,M9S,Not assigned,Not assigned,0.0,0.0
# 132,M2T,Not assigned,Not assigned,0.0,0.0
# 133,M3T,Not assigned,Not assigned,0.0,0.0
# 134,M6T,Not assigned,Not assigned,0.0,0.0
# 135,M7T,Not assigned,Not assigned,0.0,0.0
# 136,M8T,Not assigned,Not assigned,0.0,0.0
# 137,M9T,Not assigned,Not assigned,0.0,0.0
# 138,M2V,Not assigned,Not assigned,0.0,0.0
# 139,M3V,Not assigned,Not assigned,0.0,0.0
# 140,M6V,Not assigned,Not assigned,0.0,0.0
# 141,M7V,Not assigned,Not assigned,0.0,0.0
# 142,M2W,Not assigned,Not assigned,0.0,0.0
# 143,M3W,Not assigned,Not assigned,0.0,0.0
# 144,M6W,Not assigned,Not assigned,0.0,0.0
# 145,M7W,Not assigned,Not assigned,0.0,0.0
# 146,M2X,Not assigned,Not assigned,0.0,0.0
# 147,M3X,Not assigned,Not assigned,0.0,0.0
# 148,M6X,Not assigned,Not assigned,0.0,0.0
# 149,M7X,Not assigned,Not assigned,0.0,0.0
# 150,M9X,Not assigned,Not assigned,0.0,0.0
# 151,M1Y,Not assigned,Not assigned,0.0,0.0
# 152,M2Y,Not assigned,Not assigned,0.0,0.0
# 153,M3Y,Not assigned,Not assigned,0.0,0.0
# 154,M5Y,Not assigned,Not assigned,0.0,0.0
# 155,M6Y,Not assigned,Not assigned,0.0,0.0
# 156,M9Y,Not assigned,Not assigned,0.0,0.0
# 157,M1Z,Not assigned,Not assigned,0.0,0.0
# 158,M2Z,Not assigned,Not assigned,0.0,0.0
# 159,M3Z,Not assigned,Not assigned,0.0,0.0
# 160,M4Z,Not assigned,Not assigned,0.0,0.0
# 161,M5Z,Not assigned,Not assigned,0.0,0.0
# 162,M6Z,Not assigned,Not assigned,0.0,0.0
# 163,M7Z,Not assigned,Not assigned,0.0,0.0
# 164,M9Z,Not assigned,Not assigned,0.0,0.0
# 165,M3J,North York,Northwood Park,43.7541351,-79.50448
# 166,M9W,Etobicoke,Northwest,43.6465466,-79.4195263
# 167,M4R,Central Toronto,North Toronto West,43.6465466,-79.4195263
# 168,M6L,North York,North Park,43.7186899,-79.4775337
# 169,M5R,Central Toronto,North Midtown,43.7051999,-79.39741552147335
# 170,M2M,North York,Newtonbrook,43.7938863,-79.42567902301055
# 171,M8V,Etobicoke,New Toronto,43.6007625,-79.505264
# 172,M9V,Etobicoke,Mount Olive,43.653963,-79.387207
# 173,M6M,York,Mount Dennis,43.6869597,-79.4895513
# 174,M1E,Scarborough,Morningside,43.7826012,-79.2049579
# 175,M4T,Central Toronto,Moore Park,43.6903876,-79.3832965
# 176,M8X,Etobicoke,Montgomery Road,43.6490313,-79.5188556
# 177,M8V,Etobicoke,Mimico South,43.6166773,-79.4968048
# 178,M8Z,Etobicoke,Mimico NW,43.6166773,-79.4968048
# 179,M8Y,Etobicoke,Mimico NE,43.6166773,-79.4968048
# 180,M1V,Scarborough,Milliken,43.8231743,-79.3017626
# 181,M1R,Scarborough,Maryvale,43.7590508,-79.3102297
# 182,M9R,Etobicoke,Martin Grove Gardens,43.6873105,-79.561967
# 183,M9B,Etobicoke,Martin Grove,43.6449033,-79.3818364
# 184,M9C,Etobicoke,Markland Wood,43.63123865,-79.58543401986114
# 185,M1B,Scarborough,Malvern,43.8091955,-79.2217008
# 186,M8W,Etobicoke,Long Branch,43.59200455,-79.54536450659592
# 276,M5E,Downtown Toronto,Berczy Park,43.64798435,-79.37539591138858
# 277,M5M,North York,Bedford Park,43.7373876,-79.4109253
# 278,M9V,Etobicoke,Beaumond Heights,0.0,0.0
# 279,M2K,North York,Bayview Village,43.7691966,-79.3766617
# 280,M5V,Downtown Toronto,Bathurst Quay,43.6357905,-79.398329
# 281,M3H,North York,Bathurst Manor,43.76389295,-79.45636693710946
# 282,M8W,Etobicoke,Alderwood,43.6017173,-79.5452325
# 283,M9V,Etobicoke,Albion Gardens,43.7416654,-79.58454336862486
# 284,M1V,Scarborough,Agincourt North,43.8080383,-79.2664391
# 285,M1S,Scarborough,Agincourt,43.7853531,-79.2785494
# 286,M5H,Downtown Toronto,Adelaide,43.65082325,-79.37793584643234
# finish

# %%
outputFile = "Toronto_Neighbourhood_Coordinates.csv"

# %%
#This one doesn't work, so I will comment this
#df_postalcode.to_csv(outputFile, encoding="utf-8")
#with open(outputFile, 'rb') as data:
#     client_c8e4850bd8dc439d8772288cbd371cd8.upload_fileobj(data,  bucket_id, outputFile)
        
#print('finish')
# Out:
# finish

# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='539dfb05-329b-43a1-899d-d02c237b0ca3', project_access_token='p-d344efbe810a87640107d144b70e99fddc1e30f4')
pc = project.project_context

project.save_data(data=df_postalcode.to_csv(index=False),file_name=outputFile,overwrite=True)

print('finish')
# Out:
# finish

# %%
from project_lib import Project
project = Project(None, '**************', '**************')
pc = project.project_context

# %% [markdown]
# After we got dataframe of Toronto geospatial coordinate, we will merge dataframe of Toronto postal code list and dataframe Toronto geospatial coordinate so we have new dataframe contains Toronto postal code list and it's location

# %%
df_postalcode
# Out:
#     Postcode           Borough  \
# 0        M5R   Central Toronto
# 1        M3J        North York
# 2        M2P        North York
# 3        M2L        North York
# 4        M4C         East York
# 5        M4B         East York
# 6        M1G       Scarborough
# 7        M3H        North York
# 8        M2R        North York
# 9        M2N        North York
# 10       M2M        North York
# 11       M1P       Scarborough
# 12       M1R       Scarborough
# 13       M9N              York
# 14       M9P         Etobicoke
# 15       M1E       Scarborough
# 16       M9B         Etobicoke
# 17       M4A        North York
# 18       M5L  Downtown Toronto
# 19       M6L        North York
# 20       M1X       Scarborough
# 21       M5S  Downtown Toronto
# 22       M5J  Downtown Toronto
# 23       M5X  Downtown Toronto
# 24       M6J      West Toronto
# 25       M5J  Downtown Toronto
# 26       M5K  Downtown Toronto
# 27       M4H         East York
# 28       M9V         Etobicoke
# 29       M8Z         Etobicoke
# 30       M8Y         Etobicoke
# 31       M8X         Etobicoke
# 32       M6P      West Toronto
# 33       M6N              York
# 34       M4K      East Toronto
# 35       M4L      East Toronto
# 36       M4E      East Toronto
# 37       M5R   Central Toronto
# 38       M1T       Scarborough
# 39       M6S      West Toronto
# 40       M8Y         Etobicoke
# 41       M4V   Central Toronto
# 42       M4T   Central Toronto
# 43       M1T       Scarborough
# 44       M4M      East Toronto
# 45       M5W  Downtown Toronto
# 46       M1V       Scarborough
# 47       M9R         Etobicoke
# 48       M5C  Downtown Toronto
# 49       M4X  Downtown Toronto
# 50       M9V         Etobicoke
# 51       M8Z         Etobicoke
# 52       M5V  Downtown Toronto
# 53       M4V   Central Toronto
# 54       M6M              York
# 55       M9V         Etobicoke
# 56       M2L        North York
# 57       M1M       Scarborough
# 58       M1J       Scarborough
# 59       M1P       Scarborough
# 60       M5B  Downtown Toronto
# 61       M6N              York
# 62       M6S      West Toronto
# 63       M8Z         Etobicoke
# 64       M8Y         Etobicoke
# 65       M1C       Scarborough
# 66       M1B       Scarborough
# 67       M5N   Central Toronto
# 68       M4W  Downtown Toronto
# 69       M6R      West Toronto
# 70       M4K      East Toronto
# 71       M9R         Etobicoke
# 72       M5H  Downtown Toronto
# 73       M4V   Central Toronto
# 74       M5V  Downtown Toronto
# 75       M7A  Downtown Toronto
# 76       M9B         Etobicoke
# 77       M1C       Scarborough
# 78       M3A        North York
# 79       M4B         East York
# 80       M6K      West Toronto
# 81       M6R      West Toronto
# 82       M2J        North York
# 83       M8Y         Etobicoke
# 84       M8X         Etobicoke
# 85       M9C         Etobicoke
# 86       M1L       Scarborough
# 87       M1A      Not assigned
# 88       M2A      Not assigned
# 89       M8A      Not assigned
# 90       M9A      Queen's Park
# 91       M2B      Not assigned
# 92       M7B      Not assigned
# 93       M8B      Not assigned
# 94       M2C      Not assigned
# 95       M7C      Not assigned
# 96       M8C      Not assigned
# 97       M2E      Not assigned
# 98       M3E      Not assigned
# 99       M7E      Not assigned
# 100      M8E      Not assigned
# 101      M9E      Not assigned
# 102      M2G      Not assigned
# 103      M3G      Not assigned
# 104      M7G      Not assigned
# 105      M8G      Not assigned
# 106      M9G      Not assigned
# 107      M7H      Not assigned
# 108      M8H      Not assigned
# 109      M9H      Not assigned
# 110      M7J      Not assigned
# 111      M8J      Not assigned
# 112      M9J      Not assigned
# 113      M7K      Not assigned
# 114      M8K      Not assigned
# 115      M9K      Not assigned
# 116      M7L      Not assigned
# 117      M8L      Not assigned
# 118      M7M      Not assigned
# 119      M8M      Not assigned
# 120      M7N      Not assigned
# 121      M8N      Not assigned
# 122      M3P      Not assigned
# 123      M7P      Not assigned
# 124      M8P      Not assigned
# 125      M3R      Not assigned
# 126      M8R      Not assigned
# 127      M2S      Not assigned
# 128      M3S      Not assigned
# 129      M7S      Not assigned
# 130      M8S      Not assigned
# 131      M9S      Not assigned
# 132      M2T      Not assigned
# 133      M3T      Not assigned
# 134      M6T      Not assigned
# 135      M7T      Not assigned
# 136      M8T      Not assigned
# 137      M9T      Not assigned
# 138      M2V      Not assigned
# 139      M3V      Not assigned
# 140      M6V      Not assigned
# 141      M7V      Not assigned
# 142      M2W      Not assigned
# 143      M3W      Not assigned
# 144      M6W      Not assigned
# 145      M7W      Not assigned
# 146      M2X      Not assigned
# 147      M3X      Not assigned
# 148      M6X      Not assigned
# 149      M7X      Not assigned
# 150      M9X      Not assigned
# 151      M1Y      Not assigned
# 152      M2Y      Not assigned
# 153      M3Y      Not assigned
# 154      M5Y      Not assigned
# 155      M6Y      Not assigned
# 156      M9Y      Not assigned
# 157      M1Z      Not assigned
# 158      M2Z      Not assigned
# 159      M3Z      Not assigned
# 160      M4Z      Not assigned
# 161      M5Z      Not assigned
# 162      M6Z      Not assigned
# 163      M7Z      Not assigned
# 164      M9Z      Not assigned
# 165      M3J        North York
# 166      M9W         Etobicoke
# 167      M4R   Central Toronto
# 168      M6L        North York
# 169      M5R   Central Toronto
# 170      M2M        North York
# 171      M8V         Etobicoke
# 172      M9V         Etobicoke
# 173      M6M              York
# 174      M1E       Scarborough
# 175      M4T   Central Toronto
# 176      M8X         Etobicoke
# 177      M8V         Etobicoke
# 178      M8Z         Etobicoke
# 179      M8Y         Etobicoke
# 180      M1V       Scarborough
# 181      M1R       Scarborough
# 182      M9R         Etobicoke
# 183      M9B         Etobicoke
# 184      M9C         Etobicoke
# 185      M1B       Scarborough
# 186      M8W         Etobicoke
# 187      M6J      West Toronto
# 188      M4G         East York
# 189      M4N   Central Toronto
# 190      M5M        North York
# 191      M6A        North York
# 192      M6A        North York
# 193      M1W       Scarborough
# 194      M1V       Scarborough
# 195      M8Z         Etobicoke
# 196      M8Y         Etobicoke
# 197      M9R         Etobicoke
# 198      M8Y         Etobicoke
# 199      M5V  Downtown Toronto
# 200      M5H  Downtown Toronto
# 201      M5T  Downtown Toronto
# 202      M1K       Scarborough
# 203      M6M              York
# 204      M9V         Etobicoke
# 205      M9B         Etobicoke
# 206      M5V  Downtown Toronto
# 207      M1K       Scarborough
# 208      M4L      East Toronto
# 209      M6C              York
# 210      M9M        North York
# 211      M9V         Etobicoke
# 212      M9L        North York
# 213      M8V         Etobicoke
# 214      M8Y         Etobicoke
# 215      M2H        North York
# 216      M1C       Scarborough
# 217      M6P      West Toronto
# 218      M2J        North York
# 219      M5V  Downtown Toronto
# 220      M5J  Downtown Toronto
# 221      M5A  Downtown Toronto
# 222      M5S  Downtown Toronto
# 223      M1E       Scarborough
# 224      M5T  Downtown Toronto
# 225      M1L       Scarborough
# 226      M6B        North York
# 227      M5B  Downtown Toronto
# 228      M5P   Central Toronto
# 229      M4V   Central Toronto
# 230      M5P   Central Toronto
# 231      M3C        North York
# 232      M5X  Downtown Toronto
# 233      M2J        North York
# 234      M6K      West Toronto
# 235      M9C         Etobicoke
# 236      M9M        North York
# 237      M4J         East York
# 238      M1K       Scarborough
# 239      M6H      West Toronto
# 240      M3L        North York
# 241      M3N        North York
# 242      M3H        North York
# 243      M3K        North York
# 244      M3M        North York
# 245      M6L        North York
# 246      M6H      West Toronto
# 247      M1P       Scarborough
# 248      M3C        North York
# 249      M3B        North York
# 250      M5K  Downtown Toronto
# 251      M6M              York
# 252      M4V   Central Toronto
# 253      M4P   Central Toronto
# 254      M4S   Central Toronto
# 255      M5L  Downtown Toronto
# 256      M5V  Downtown Toronto
# 240                                     Downsview West  43.749299 -79.462248
# 241                                Downsview Northwest  43.749299 -79.462248
# 242                                    Downsview North  43.749299 -79.462248
# 243                                     Downsview East  43.749299 -79.462248
# 244                                  Downsview Central  43.749299 -79.462248
# 245                                          Downsview  43.749299 -79.462248
# 246                                 Dovercourt Village  43.665307 -79.432636
# 247                                        Dorset Park  43.752847 -79.282067
# 248                                    Don Mills South  43.775347 -79.345944
# 249                                    Don Mills North  43.775347 -79.345944
# 250                                    Design Exchange  43.647741 -79.380115
# 251                                            Del Ray   0.000000   0.000000
# 252                                          Deer Park  43.688090 -79.394093
# 253                                   Davisville North  43.697936 -79.397291
# 254                                         Davisville  43.697936 -79.397291
# 255                                     Commerce Court  43.648095 -79.379025
# 256                                           CN Tower  43.642564 -79.387087
# 257                                         Cloverdale  43.633637 -79.549745
# 258                                     Cliffside West  43.711170 -79.248177
# 259                                          Cliffside  43.711170 -79.248177
# 260                                         Cliffcrest  43.721939 -79.236232
# 261                                     Clarks Corners  43.796410 -79.297795
# 262                                           Clairlea  43.708823 -79.295986
# 263                               Church and Wellesley  43.665524 -79.383801
# 264                                           Christie  43.664111 -79.418405
# 265                                          Chinatown  43.652924 -79.398032
# 266                                        CFB Toronto   0.000000   0.000000
# 267                                 Central Bay Street   0.000000   0.000000
# 268                                          Cedarbrae  43.756467 -79.226692
# 269              Canada Post Gateway Processing Centre   0.000000   0.000000
# 270                                Caledonia-Fairbanks   0.000000   0.000000
# 271                                        Cabbagetown  43.664473 -79.366986
# 272  Business Reply Mail Processing Centre 969 Eastern   0.000000   0.000000
# 273                                           Brockton  43.650917 -79.440022
# 274                                  Bloordale Gardens  43.635317 -79.563674
# 275                                        Birch Cliff  43.702112 -79.260091
# 276                                        Berczy Park  43.647984 -79.375396
# 277                                       Bedford Park  43.737388 -79.410925
# 278                                   Beaumond Heights   0.000000   0.000000
# 279                                    Bayview Village  43.769197 -79.376662
# 280                                      Bathurst Quay  43.635790 -79.398329
# 281                                     Bathurst Manor  43.763893 -79.456367
# 282                                          Alderwood  43.601717 -79.545232
# 283                                     Albion Gardens  43.741665 -79.584543
# 284                                    Agincourt North  43.808038 -79.266439
# 285                                          Agincourt  43.785353 -79.278549
# 286                                           Adelaide  43.650823 -79.377936

# %%
df_TorontoPostalCodeGeospatial = pd.merge( df_postalcode, df_geospatial,  on='Postcode')
df_TorontoPostalCodeGeospatial.head()
# Out:
#   Postcode          Borough    Neighbourhood  Latitude  Longitude
# 0      M5R  Central Toronto        Yorkville  43.67271 -79.405678
# 1      M5R  Central Toronto        The Annex  43.67271 -79.405678
# 2      M5R  Central Toronto    North Midtown  43.67271 -79.405678
# 3      M3J       North York  York University  43.76798 -79.487262
# 4      M3J       North York   Northwood Park  43.76798 -79.487262

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode("The Annex, Toronto, Ontario")
print(location.address)
print(location.latitude, location.longitude)
#print(location.raw)
# Out:
# The Annex, University—Rosedale, Old Toronto, Toronto, Golden Horseshoe, Ontario, M5T 2E9, Canada
# 43.6703377 -79.407117
